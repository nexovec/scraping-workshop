# %% [markdown]
# # Ukázka: API (OpenWeather.org 🌤️)
#
# Předpověď na 4 dny: https://openweathermap.org/api/hourly-forecast#name5
#
# Jak vypadá odpověď: https://openweathermap.org/api/hourly-forecast#example_JSON

# %%
# Nezapomeň si doinstalovat knihovnu 'requests':
#     python -m pip install requests

import requests

token = 'a24f2ac43e51111d1186ca7d782a8344'
url = 'http://api.openweathermap.org/data/2.5/forecast'

req_params = {
    'APIKEY': token,
    'q': 'Praha',
    'units': 'metric'
}

response = requests.get(url, params=req_params)

# %%
response
# Out:
# <Response [200]>

# %%
response.url
# Out:
# 'http://api.openweathermap.org/data/2.5/forecast?APIKEY=a24f2ac43e51111d1186ca7d782a8344&q=Praha&units=metric'

# %%
forecast = response.json()
forecast
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1694552400,
#    'main': {'temp': 22.76,
#     'feels_like': 22.76,
#     'temp_min': 21.71,
#     'temp_max': 22.76,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 989,
#     'humidity': 64,
#     'temp_kf': 1.05},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 1.88, 'deg': 188, 'gust': 2.71},
#    'visibility': 10000,
#    'pop': 0.4,
#    'rain': {'3h': 0.11},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-12 21:00:00'},
#   {'dt': 1694563200,
#    'main': {'temp': 21.92,
#     'feels_like': 21.89,
#     'temp_min': 20.23,
#     'temp_max': 21.92,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 988,
#     'humidity': 66,
#     'temp_kf': 1.69},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 24},
#    'wind': {'speed': 1.49, 'deg': 179, 'gust': 1.76},
#    'visibility': 10000,
#    'pop': 0.05,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-13 00:00:00'},
#   {'dt': 1694574000,
#    'main': {'temp': 20.03,
#     'feels_like': 20.02,
#     'temp_min': 18.67,
#     'temp_max': 20.03,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 989,
#     'humidity': 74,
#     'temp_kf': 1.36},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 45},
#    'wind': {'speed': 2.11, 'deg': 226, 'gust': 2.93},
#    'visibility': 10000,
#    'pop': 0.61,
#    'rain': {'3h': 0.65},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-13 03:00:00'},
#   {'dt': 1694584800,
#    'main': {'temp': 20.22,
#     'feels_like': 20.31,
#     'temp_min': 20.22,
#     'temp_max': 20.22,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 989,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 2.46, 'deg': 228, 'gust': 6.7},
#    'visibility': 10000,
#    'pop': 0.55,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-13 06:00:00'},
#   {'dt': 1694595600,
#    'main': {'temp': 25.06,
#     'feels_like': 25.03,
#     'temp_min': 25.06,
#     'temp_max': 25.06,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 990,
#     'humidity': 54,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 5.67, 'deg': 265, 'gust': 7.59},
#    'visibility': 10000,
#    'pop': 0.19,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-13 09:00:00'},
#   {'dt': 1694606400,
#    'main': {'temp': 27.01,
#     'feels_like': 27.08,
#     'temp_min': 27.01,
#     'temp_max': 27.01,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 991,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 6.07, 'deg': 278, 'gust': 7.46},
#    'visibility': 10000,
#    'pop': 0.03,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-13 12:00:00'},
#   {'dt': 1694617200,
#    'main': {'temp': 24.94,
#     'feels_like': 24.77,
#     'temp_min': 24.94,
#     'temp_max': 24.94,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 991,
#     'humidity': 49,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 5.36, 'deg': 318, 'gust': 5.63},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-13 15:00:00'},
#   {'dt': 1694628000,
#    'main': {'temp': 20.53,
#     'feels_like': 20.39,
#     'temp_min': 20.53,
#     'temp_max': 20.53,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 993,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 4.71, 'deg': 356, 'gust': 7.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-13 18:00:00'},
#   {'dt': 1694638800,
#    'main': {'temp': 18.24,
#     'feels_like': 18,
#     'temp_min': 18.24,
#     'temp_max': 18.24,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 995,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 4.45, 'deg': 1, 'gust': 6.96},
#    'visibility': 10000,
#    'pop': 0.01,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-13 21:00:00'},
#   {'dt': 1694649600,
#    'main': {'temp': 14.81,
#     'feels_like': 14.46,
#     'temp_min': 14.81,
#     'temp_max': 14.81,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 996,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 3.19, 'deg': 5, 'gust': 6.84},
#    'visibility': 10000,
#    'pop': 0.01,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-14 00:00:00'},
#   {'dt': 1694660400,
#    'main': {'temp': 13.22,
#     'feels_like': 12.76,
#     'temp_min': 13.22,
#     'temp_max': 13.22,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 997,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 18},
#    'wind': {'speed': 2.37, 'deg': 357, 'gust': 4.29},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-14 03:00:00'},
#   {'dt': 1694671200,
#    'main': {'temp': 14,
#     'feels_like': 13.26,
#     'temp_min': 14,
#     'temp_max': 14,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 998,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 2.77, 'deg': 354, 'gust': 5.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-14 06:00:00'},
#   {'dt': 1694682000,
#    'main': {'temp': 18.44,
#     'feels_like': 17.49,
#     'temp_min': 18.44,
#     'temp_max': 18.44,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 998,
#     'humidity': 44,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 3.4, 'deg': 9, 'gust': 3.94},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-14 09:00:00'},
#   {'dt': 1694692800,
#    'main': {'temp': 21.85,
#     'feels_like': 20.93,
#     'temp_min': 21.85,
#     'temp_max': 21.85,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 997,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 3.25, 'deg': 10, 'gust': 3.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-14 12:00:00'},
#   {'dt': 1694703600,
#    'main': {'temp': 22.15,
#     'feels_like': 21.26,
#     'temp_min': 22.15,
#     'temp_max': 22.15,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 997,
#     'humidity': 32,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 3.35, 'deg': 21, 'gust': 3.15},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-14 15:00:00'},
#   {'dt': 1694714400,
#    'main': {'temp': 16.66,
#     'feels_like': 15.61,
#     'temp_min': 16.66,
#     'temp_max': 16.66,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 998,
#     'humidity': 47,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 25},
#    'wind': {'speed': 2.9, 'deg': 33, 'gust': 4.42},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-14 18:00:00'},
#   {'dt': 1694725200,
#    'main': {'temp': 14.19,
#     'feels_like': 13.1,
#     'temp_min': 14.19,
#     'temp_max': 14.19,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 998,
#     'humidity': 55,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 72},
#    'wind': {'speed': 1.66, 'deg': 68, 'gust': 2.32},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-14 21:00:00'},
#   {'dt': 1694736000,
#    'main': {'temp': 12.32,
#     'feels_like': 11.17,
#     'temp_min': 12.32,
#     'temp_max': 12.32,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 998,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 44},
#    'wind': {'speed': 1.1, 'deg': 83, 'gust': 1.47},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-15 00:00:00'},
#   {'dt': 1694746800,
#    'main': {'temp': 11.03,
#     'feels_like': 9.89,
#     'temp_min': 11.03,
#     'temp_max': 11.03,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 998,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 0.97, 'deg': 67, 'gust': 1.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-15 03:00:00'},
#   {'dt': 1694757600,
#    'main': {'temp': 12.56,
#     'feels_like': 11.46,
#     'temp_min': 12.56,
#     'temp_max': 12.56,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 998,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 1.13, 'deg': 67, 'gust': 1.87},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-15 06:00:00'},
#   {'dt': 1694768400,
#    'main': {'temp': 19.15,
#     'feels_like': 18.19,
#     'temp_min': 19.15,
#     'temp_max': 19.15,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 998,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 2.55, 'deg': 92, 'gust': 3.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-15 09:00:00'},
#   {'dt': 1694779200,
#    'main': {'temp': 23.07,
#     'feels_like': 22.24,
#     'temp_min': 23.07,
#     'temp_max': 23.07,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 997,
#     'humidity': 31,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 4.26, 'deg': 96, 'gust': 4.92},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-15 12:00:00'},
#   {'dt': 1694790000,
#    'main': {'temp': 23.68,
#     'feels_like': 22.97,
#     'temp_min': 23.68,
#     'temp_max': 23.68,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 995,
#     'humidity': 33,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 4.74, 'deg': 92, 'gust': 5.6},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-15 15:00:00'},
#   {'dt': 1694800800,
#    'main': {'temp': 18.07,
#     'feels_like': 17.47,
#     'temp_min': 18.07,
#     'temp_max': 18.07,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 995,
#     'humidity': 59,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 3.76, 'deg': 82, 'gust': 8.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-15 18:00:00'},
#   {'dt': 1694811600,
#    'main': {'temp': 16.13,
#     'feels_like': 15.63,
#     'temp_min': 16.13,
#     'temp_max': 16.13,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 995,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 12},
#    'wind': {'speed': 3.27, 'deg': 95, 'gust': 8.03},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-15 21:00:00'},
#   {'dt': 1694822400,
#    'main': {'temp': 15.08,
#     'feels_like': 14.52,
#     'temp_min': 15.08,
#     'temp_max': 15.08,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 995,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 2.44, 'deg': 91, 'gust': 4.63},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-16 00:00:00'},
#   {'dt': 1694833200,
#    'main': {'temp': 14.29,
#     'feels_like': 13.6,
#     'temp_min': 14.29,
#     'temp_max': 14.29,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 994,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 7},
#    'wind': {'speed': 2.64, 'deg': 93, 'gust': 6.66},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-16 03:00:00'},
#   {'dt': 1694844000,
#    'main': {'temp': 15.56,
#     'feels_like': 15.05,
#     'temp_min': 15.56,
#     'temp_max': 15.56,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 994,
#     'humidity': 72,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 19},
#    'wind': {'speed': 2.3, 'deg': 107, 'gust': 5.74},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-16 06:00:00'},
#   {'dt': 1694854800,
#    'main': {'temp': 22.39,
#     'feels_like': 21.99,
#     'temp_min': 22.39,
#     'temp_max': 22.39,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 994,
#     'humidity': 50,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 3},
#    'wind': {'speed': 4.09, 'deg': 140, 'gust': 5.54},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-16 09:00:00'},
#   {'dt': 1694865600,
#    'main': {'temp': 26.4,
#     'feels_like': 26.4,
#     'temp_min': 26.4,
#     'temp_max': 26.4,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 993,
#     'humidity': 42,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 1},
#    'wind': {'speed': 4.11, 'deg': 153, 'gust': 4.92},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-16 12:00:00'},
#   {'dt': 1694876400,
#    'main': {'temp': 26.92,
#     'feels_like': 26.85,
#     'temp_min': 26.92,
#     'temp_max': 26.92,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 992,
#     'humidity': 41,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 3.73, 'deg': 155, 'gust': 4.5},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-16 15:00:00'},
#   {'dt': 1694887200,
#    'main': {'temp': 21.6,
#     'feels_like': 21.38,
#     'temp_min': 21.6,
#     'temp_max': 21.6,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 992,
#     'humidity': 60,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 35},
#    'wind': {'speed': 1.82, 'deg': 127, 'gust': 2.36},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-16 18:00:00'},
#   {'dt': 1694898000,
#    'main': {'temp': 19.3,
#     'feels_like': 19.11,
#     'temp_min': 19.3,
#     'temp_max': 19.3,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 993,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 1.13, 'deg': 170, 'gust': 1.91},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-16 21:00:00'},
#   {'dt': 1694908800,
#    'main': {'temp': 17.9,
#     'feels_like': 17.7,
#     'temp_min': 17.9,
#     'temp_max': 17.9,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 993,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 0.45, 'deg': 274, 'gust': 0.9},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-17 00:00:00'},
#   {'dt': 1694919600,
#    'main': {'temp': 16.61,
#     'feels_like': 16.44,
#     'temp_min': 16.61,
#     'temp_max': 16.61,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 993,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 0.76, 'deg': 240, 'gust': 0.9},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-17 03:00:00'},
#   {'dt': 1694930400,
#    'main': {'temp': 18.05,
#     'feels_like': 17.87,
#     'temp_min': 18.05,
#     'temp_max': 18.05,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 993,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 49},
#    'wind': {'speed': 0.52, 'deg': 228, 'gust': 0.81},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-17 06:00:00'},
#   {'dt': 1694941200,
#    'main': {'temp': 24.47,
#     'feels_like': 24.36,
#     'temp_min': 24.47,
#     'temp_max': 24.47,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 994,
#     'humidity': 53,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 0},
#    'wind': {'speed': 0.85, 'deg': 237, 'gust': 1.51},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-17 09:00:00'},
#   {'dt': 1694952000,
#    'main': {'temp': 28.6,
#     'feels_like': 28.06,
#     'temp_min': 28.6,
#     'temp_max': 28.6,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 993,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 2},
#    'wind': {'speed': 1.14, 'deg': 182, 'gust': 2.02},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-17 12:00:00'},
#   {'dt': 1694962800,
#    'main': {'temp': 28.94,
#     'feels_like': 28.22,
#     'temp_min': 28.94,
#     'temp_max': 28.94,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 992,
#     'humidity': 36,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 4},
#    'wind': {'speed': 1.64, 'deg': 176, 'gust': 2.67},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2023-09-17 15:00:00'},
#   {'dt': 1694973600,
#    'main': {'temp': 23.73,
#     'feels_like': 23.52,
#     'temp_min': 23.73,
#     'temp_max': 23.73,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 992,
#     'humidity': 52,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 37},
#    'wind': {'speed': 1.74, 'deg': 147, 'gust': 2.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2023-09-17 18:00:00'}],
#  'city': {'id': 3067696,
#   'name': 'Prague',
#   'coord': {'lat': 50.088, 'lon': 14.4208},
#   'country': 'CZ',
#   'population': 1165581,
#   'timezone': 7200,
#   'sunrise': 1694493182,
#   'sunset': 1694539490}}

# %%
for sample in forecast['list'][:15]:
    date = sample["dt_txt"]
    temp = sample['main']['temp']

    print(f'{date} {temp}')
# Out:
# 2023-09-12 21:00:00 22.76
# 2023-09-13 00:00:00 21.92
# 2023-09-13 03:00:00 20.03
# 2023-09-13 06:00:00 20.22
# 2023-09-13 09:00:00 25.06
# 2023-09-13 12:00:00 27.01
# 2023-09-13 15:00:00 24.94
# 2023-09-13 18:00:00 20.53
# 2023-09-13 21:00:00 18.24
# 2023-09-14 00:00:00 14.81
# 2023-09-14 03:00:00 13.22
# 2023-09-14 06:00:00 14
# 2023-09-14 09:00:00 18.44
# 2023-09-14 12:00:00 21.85
# 2023-09-14 15:00:00 22.15

# %%
for sample in forecast['list'][:15]:
    date = sample["dt_txt"]
    temp = sample['main']['temp']
    line = int(temp) * '.'

    print(f'{date} {line} {temp} °C')
# Out:
# 2023-09-12 21:00:00 ...................... 22.76 °C
# 2023-09-13 00:00:00 ..................... 21.92 °C
# 2023-09-13 03:00:00 .................... 20.03 °C
# 2023-09-13 06:00:00 .................... 20.22 °C
# 2023-09-13 09:00:00 ......................... 25.06 °C
# 2023-09-13 12:00:00 ........................... 27.01 °C
# 2023-09-13 15:00:00 ........................ 24.94 °C
# 2023-09-13 18:00:00 .................... 20.53 °C
# 2023-09-13 21:00:00 .................. 18.24 °C
# 2023-09-14 00:00:00 .............. 14.81 °C
# 2023-09-14 03:00:00 ............. 13.22 °C
# 2023-09-14 06:00:00 .............. 14 °C
# 2023-09-14 09:00:00 .................. 18.44 °C
# 2023-09-14 12:00:00 ..................... 21.85 °C
# 2023-09-14 15:00:00 ...................... 22.15 °C

# %%
def get_emoji(weather):
    emoji_map = {
        'Snow': '\N{SNOWFLAKE}',
        'Rain': '\N{UMBRELLA WITH RAIN DROPS}',
        'Clouds': '\N{WHITE SUN WITH SMALL CLOUD}',
        'Clear': '\N{SUN WITH FACE}'
    }

    return emoji_map.get(weather, '?')

for sample in forecast['list'][:15]:
    date = sample["dt_txt"]
    temp = sample['main']['temp']
    line = int(temp) * '.'
    picture = get_emoji(sample['weather'][0]['main'])


    print(f'{date} {picture} {line} {temp} \N{DEGREE CELSIUS}')
# Out:
# 2023-09-12 21:00:00 ☔ ...................... 22.76 ℃
# 2023-09-13 00:00:00 🌤 ..................... 21.92 ℃
# 2023-09-13 03:00:00 ☔ .................... 20.03 ℃
# 2023-09-13 06:00:00 🌤 .................... 20.22 ℃
# 2023-09-13 09:00:00 🌤 ......................... 25.06 ℃
# 2023-09-13 12:00:00 🌤 ........................... 27.01 ℃
# 2023-09-13 15:00:00 🌤 ........................ 24.94 ℃
# 2023-09-13 18:00:00 🌤 .................... 20.53 ℃
# 2023-09-13 21:00:00 🌤 .................. 18.24 ℃
# 2023-09-14 00:00:00 🌤 .............. 14.81 ℃
# 2023-09-14 03:00:00 🌤 ............. 13.22 ℃
# 2023-09-14 06:00:00 🌞 .............. 14 ℃
# 2023-09-14 09:00:00 🌞 .................. 18.44 ℃
# 2023-09-14 12:00:00 🌞 ..................... 21.85 ℃
# 2023-09-14 15:00:00 🌞 ...................... 22.15 ℃
